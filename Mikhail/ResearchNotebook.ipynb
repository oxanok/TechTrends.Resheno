# %%
from GooglePatents.API import GooglePatents

# %%
googlePatents = GooglePatents()

# %%
googlePatents.setQuery('Deep learning neural interfaces')

# %%
googlePatents.getAllPagePatents()
# Out:
#                                                  title  \
# 0     Navigational control of robotic systems and o...
# 1     Systems and methods for adaptive neural decoding
# 2     Methods for closed-loop neural-machine interf...
# 3     System and method for applying a deep learnin...
# 4                 Accelerator for deep neural networks
# ..                                                 ...
# 995   Method and device for detecting an anatomical...
# 996    HARDWARE-BASED ACCELERATION OF AN OPTICAL RIVER
# 997   Text processing model training method, and te...
# 998   Systems and methods for process design includ...
# 999                       Policy based path management
#
#                                                snippet priority_date  \
# 0     The Developmental Network incorporates a Turi...    2015-07-10
# 1     This invention is directed to a system and me...    2012-08-06
# 2     Brain-Machine Interface (BMI) systems or move...    2013-07-03
# ...

# %%
googlePatents.getPatentsDetailsFromJson('patents.json')
# Out:
#                                                  title publicationNumber  \
# 0    Navigational control of robotic systems and ot...      US10343279B2
# 1     Systems and methods for adaptive neural decoding    WO2014025765A2
# 2    Methods for closed-loop neural-machine interfa...      US10092205B2
# 3    System and method for applying a deep learning...      US10504020B2
# 4                 Accelerator for deep neural networks      US10387771B2
# ..                                                 ...               ...
# 995  Method and device for detecting an anatomical ...   US20200202557A1
# 996    HARDWARE-BASED ACCELERATION OF AN OPTICAL RIVER  DE102020122943A1
# 997  Text processing model training method, and tex...    WO2021047286A1
# 998  Systems and methods for process design includi...   US20210081876A1
# 999                       Policy based path management      US10992533B1
#
#     countryCode    countryName  \
# 0            US  United States
# ...
